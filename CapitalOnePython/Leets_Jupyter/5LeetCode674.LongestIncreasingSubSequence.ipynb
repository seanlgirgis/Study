# %% [markdown]
#  Here's a coding exercise based on **LeetCode 674: Longest Continuous Increasing Subsequence**:
#
# ---
#
# ## 🎯 Problem: Longest Continuous Increasing Subsequence (LCIS)
#
# **Difficulty:** Easy
# **Pattern:** Array / Sliding Window / One Pass
#
# ### Problem Statement
# Given an unsorted array of integers `nums`, return the **length** of the **longest continuous increasing subsequence** (i.e. subarray).
#
# A **continuous increasing subsequence** is defined by two indices `l` and `r` (`l < r`) such that it is `[nums[l], nums[l + 1], ..., nums[r - 1], nums[r]]` and for each `l <= i < r`, `nums[i] < nums[i + 1]`.
#
# ---
#
# ### Examples
#
# | Input | Output | Explanation |
# |-------|--------|-------------|
# | `[1,3,5,4,7]` | `3` | The longest continuous increasing subsequence is `[1,3,5]` with length 3. Note: `[1,3,5,7]` is not valid because 5 → 4 breaks continuity. |
# | `[2,2,2,2,2]` | `1` | No increasing pairs, so longest is any single element: length 1. |
# | `[1,3,5,7]` | `4` | Entire array is strictly increasing. |
#
# ---
#
# ### Constraints
# - `1 <= nums.length <= 10^4`
# - `-10^9 <= nums[i] <= 10^9`
#
# ---
#
# ## 🧠 Hints (Reveal as needed)
#
# <details>
# <summary>Hint 1: One-pass tracking</summary>
#
# You only need to track the **current** increasing streak length. When `nums[i] > nums[i-1]`, extend the streak. Otherwise, reset to 1.
#
# </details>
#
# <details>
# <summary>Hint 2: Variables needed</summary>
#
# - `current_length` — length of current increasing streak
# - `max_length` — maximum found so far
#
# </details>
#
# <details>
# <summary>Hint 3: Edge case</summary>
#
# Minimum answer is always `1` (single element array or all equal elements).
#
# </details>
#
# ---
#
# ## 📝 Starter Code
#
# ```python
# def findLengthOfLCIS(nums: list[int]) -> int:
#     if not nums:
#         return 0
#
#     # Your code here
#     pass
#
# # Test cases
# print(findLengthOfLCIS([1, 3, 5, 4, 7]))      # Expected: 3
# print(findLengthOfLCIS([2, 2, 2, 2, 2]))      # Expected: 1
# print(findLengthOfLCIS([1, 3, 5, 7]))         # Expected: 4
# print(findLengthOfLCIS([5]))                  # Expected: 1
# print(findLengthOfLCIS([1, 2, 3, 0, 1, 2, 3, 4]))  # Expected: 5 (last 5 elements)
# ```
#
# ---
#
# ## ⏱️ Challenge Yourself
#
# | Challenge | Goal |
# |-----------|------|
# | **Time** | Solve in < 10 minutes |
# | **Space** | O(1) extra space |
# | **Variations** | Can you return the actual subsequence (not just length)? |
#
# ---
#
# Want me to provide the solution, or test cases with edge cases like negative numbers or single elements?

# %%
from typing import List

class Solution:

    def findLengthOfLCIS(self,nums: list[int]) -> int:
        n = len(nums)
        if n == 0:
            return 0
        ret = 0
        current_length = 0
        max_length = 0
        for i, num in enumerate(nums):
            if i == 0:
                current_length = 1
                max_length = 1
            else:
                if num > nums[i-1]:
                    current_length += 1
                else:
                    current_length = 1
                max_length = max(max_length, current_length)
        return max_length


    def runSuite(self, test_cases: List[tuple[List[int], int]]):
        for i, (lst, expected) in enumerate(test_cases):
            found = self.findLengthOfLCIS(lst)
            if len(lst) > 10:
                if found != expected:
                    print(f"Test {i} failed")
                else:
                    print(f"Test {i} passed")
            else:   
                if found != expected:
                    print(f"Test failed for {lst}: Expected {expected}, got {found}")
                else:
                    print(f"Test passed for {lst}: Expected {expected}, got {found}")

test_cases: List[tuple[List[int], int]] = [
    ([1, 3, 5, 4, 7], 3)
    ,([],0)
    ,([2, 2, 2, 2, 2],1)
    ,([1, 2, 3, 0, 1, 2, 3, 4],5)
     ,([8],1)
]

sol: Solution = Solution()
sol.runSuite(test_cases)
# Out:
# Test passed for [1, 3, 5, 4, 7]: Expected 3, got 3
# Test passed for []: Expected 0, got 0
# Test passed for [2, 2, 2, 2, 2]: Expected 1, got 1
# Test passed for [1, 2, 3, 0, 1, 2, 3, 4]: Expected 5, got 5
# Test passed for [8]: Expected 1, got 1
