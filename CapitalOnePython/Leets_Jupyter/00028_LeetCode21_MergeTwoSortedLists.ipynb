# %% [markdown]
# # LeetCode 21. Merge Two Sorted Lists
#
# You are given the heads of two sorted linked lists `list1` and `list2`.
#
# Merge the two lists in a one **sorted** list. The list should be made by splicing together the nodes of the first two lists.
#
# Return *the head of the merged linked list*.
#
#
#
# **Example 1:**
#
# ![](https://assets.leetcode.com/uploads/2020/10/03/merge_ex1.jpg)
#
# ```
# Input: list1 = [1,2,4], list2 = [1,3,4]
# Output: [1,1,2,3,4,4]
# ```
#
# **Example 2:**
#
# ```
# Input: list1 = [], list2 = []
# Output: []
# ```
#
# **Example 3:**
#
# ```
# Input: list1 = [], list2 = [0]
# Output: [0]
# ```
#
#
#
# **Constraints:**
#
# *   The number of nodes in both lists is in the range `[0, 50]`.
# *   `-100 <= Node.val <= 100`
# *   Both `list1` and `list2` are sorted in **non-decreasing** order.

# %% [markdown]
# # Seans Solution

# %%
from typing import Optional

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        head = ListNode()
        current = head
        while list1 and list2:
            if list1.val < list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next
            current = current.next
        # If we reach the end of one list Just plug in the other
        if list1:
            current.next = list1
        elif list2:
            current.next = list2
        return head.next
# Test Harness

# Helper function to convert list to linked list
def to_linked_list(lst):
    dummy = ListNode(0)
    current = dummy
    for val in lst:
        current.next = ListNode(val)
        current = current.next
    return dummy.next

# Helper function to convert linked list to list
def to_list(node):
    result = []
    while node:
        result.append(node.val)
        node = node.next
    return result

def run_tests(solution_class):
    solver = solution_class()
    
    test_cases = [
        ([1,2,4], [1,3,4], [1,1,2,3,4,4]),
        ([], [], []),
        ([], [0], [0]),
        ([2], [1], [1,2]),
        ([5,10,15], [2,3,20], [2,3,5,10,15,20])
    ]
    
    for i, (l1, l2, expected) in enumerate(test_cases):
        list1 = to_linked_list(l1)
        list2 = to_linked_list(l2)
        
        result_node = solver.mergeTwoLists(list1, list2)
        result_list = to_list(result_node)
        
        if result_list == expected:
            print(f"Test Case {i+1}: Passed ✅")
        else:
            print(f"Test Case {i+1}: Failed ❌")
            print(f"   Input: l1={l1}, l2={l2}")
            print(f"   Expected: {expected}")
            print(f"   Actual:   {result_list}")

run_tests(Solution)
# Out:
# Test Case 1: Passed ✅
# Test Case 2: Passed ✅
# Test Case 3: Passed ✅
# Test Case 4: Passed ✅
# Test Case 5: Passed ✅

# %%
from typing import Optional

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
        # Create a dummy node to start the merged list
        dummy = ListNode(-1)
        current = dummy
        
        # Traverse both lists
        while list1 and list2:
            if list1.val <= list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next
            current = current.next
        
        # If one list is exhausted, append the other
        if list1:
            current.next = list1
        elif list2:
            current.next = list2
            
        return dummy.next

# %%
# Test Harness

# Helper function to convert list to linked list
def to_linked_list(lst):
    dummy = ListNode(0)
    current = dummy
    for val in lst:
        current.next = ListNode(val)
        current = current.next
    return dummy.next

# Helper function to convert linked list to list
def to_list(node):
    result = []
    while node:
        result.append(node.val)
        node = node.next
    return result

def run_tests(solution_class):
    solver = solution_class()
    
    test_cases = [
        ([1,2,4], [1,3,4], [1,1,2,3,4,4]),
        ([], [], []),
        ([], [0], [0]),
        ([2], [1], [1,2]),
        ([5,10,15], [2,3,20], [2,3,5,10,15,20])
    ]
    
    for i, (l1, l2, expected) in enumerate(test_cases):
        list1 = to_linked_list(l1)
        list2 = to_linked_list(l2)
        
        result_node = solver.mergeTwoLists(list1, list2)
        result_list = to_list(result_node)
        
        if result_list == expected:
            print(f"Test Case {i+1}: Passed ✅")
        else:
            print(f"Test Case {i+1}: Failed ❌")
            print(f"   Input: l1={l1}, l2={l2}")
            print(f"   Expected: {expected}")
            print(f"   Actual:   {result_list}")

run_tests(Solution)
